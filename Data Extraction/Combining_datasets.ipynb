# %%
import pandas as pd

# %%
sentence_data = "datasets/iemocap_data.csv"
emo_data = "datasets/emotional_labels.csv"

# %%
df1 = pd.read_csv(sentence_data)
df1
# Out:
#                                                Sentence
# 0                               What's he going to say?
# 1           Maybe we should tell him before he sees it.
# 2                                            He saw it.
# 3     How could he see it?  I was the first one up; ...
# 4                        He was out here when it broke.
# ...                                                 ...
# 1840  Some, I guess.  She memorized this one, John D...
# 1841                      So she wrote a lot of poetry?
# 1842             There's another one, I can't remember.
# 1843  I remember, too, when we were--  she died at U...
# 1844                                 Mmhmm.Mmhmm.Mmhmm.
#
# [1845 rows x 1 columns]

# %%
df2 = pd.read_csv(emo_data)
df2
# Out:
#       Unnamed: 0  start_time  end_time                wav_file emotion  \
# 0              0      6.2100    9.3200  Ses01F_script01_1_F000     fru
# 1              1      9.3500   12.8955  Ses01F_script01_1_F001     xxx
# 2              2     14.3063   19.5526  Ses01F_script01_1_F002     sur
# 3              3     22.3200   24.6667  Ses01F_script01_1_F003     xxx
# 4              4     35.3799   39.0900  Ses01F_script01_1_F004     xxx
# ...          ...         ...       ...                     ...     ...
# 1814        1814    174.3900  177.1500     Ses01F_impro06_M013     neu
# 1815        1815    219.7300  221.0300     Ses01F_impro06_M014     neu
# 1816        1816    255.3500  257.3100     Ses01F_impro06_M015     neu
# 1817        1817    262.9900  266.1750     Ses01F_impro06_M016     neu
# 1818        1818    308.2400  310.0100     Ses01F_impro06_M017     xxx
#
#          val     act     dom
# 0     2.0000  2.3333  2.3333
# 1     2.0000  2.3333  1.6667
# ...

# %%
print("Sample filenames from sentences:")
print(sentences_df['iemocap_data.csv'].head())
# Out:
# Sample filenames from sentences:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'iemocap_data.csv'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sentences_df = pd.read_csv(sentence_data)
labels_df = pd.read_csv(emo_data)

# Merge the dataframes on the 'Filename' column
combined_df = pd.merge(sentences_df, labels_df, on='Filename')

# Save the combined dataframe to a CSV file
combined_df.to_csv(combined_output_path, index=False)

print(f"Combined sentences and labels have been written to {combined_output_path}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3726/2696414984.py in ?()
#       1 sentences_df = pd.read_csv(sentence_data)
#       2 labels_df = pd.read_csv(emo_data)
#       3
#       4 # Merge the dataframes on the 'Filename' column
# ----> 5 combined_df = pd.merge(sentences_df, labels_df, on='Filename')
#       6
#       7 # Save the combined dataframe to a CSV file
#       8 combined_df.to_csv(combined_output_path, index=False)
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     144     copy: bool | None = None,
#     145     indicator: str | bool = False,
#     146     validate: str | None = None,
#     147 ) -> DataFrame:
# --> 148     op = _MergeOperation(
#     149         left,
#     150         right,
# ...
